# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# Watts Strogatz with 10,000 nodes with degree $K = 80$, and $\beta = 0.2$. $b$ generated from 30 nonzero entries drawn from a $Normal(125,9)$ distribution. 1000 iterations of ADMM with $\rho = 0.5$ and $\lambda = 0.0055$.

# %%
result1 = pd.read_table("WS_10000-20-02b+0e+100n_normal*3+125_sparse_seed1_05rho_00055lambda.txt",
              header = None,
              names = ["Avg_Pred","Avg_Gen","Approx_Random"])

# %% [markdown]
# ax = result1.loc[1:21].plot(title = "WS(10000,80,0.2); b = 30xN(125,9); lambda = 0.0055", x = np.arange(1,202,10))
# ax.set_xlabel("top k nodes")
# ax.set_ylabel("recall")

# %%
ax = result1.plot(title = "WS(10000,80,0.2); b = 30xN(125,9); lambda = 0.0055", x = np.arange(1,5002,10))
ax.set_xlabel("top k nodes")
ax.set_ylabel("recall")
# Out:
# Text(0,0.5,'recall')

# %% [markdown]
# Watts Strogatz with 10,000 nodes with degree $K = 80$, and $\beta = 0.2$. $b$ generated from 30 nonzero entries drawn from a $Normal(100,9)$ distribution. 1000 iterations of ADMM with $\rho = 0.5$ and $\lambda = 0.0035$.

# %%
result2 = pd.read_table("WS_10000-20-02b+0e+100n_normal*3+100_sparse_seed1_05rho_00035lambda.txt",
             header = None,
             names = ["Avg_Pred","Avg_Gen","Approx_Random"])

# %%
ax = result2.plot(title = "WS(10000,80,0.2); b = 30xN(100,9); lambda = 0.0035", x = np.arange(1,5002,10))
ax.set_xlabel("top k nodes")
ax.set_ylabel("recall")
# Out:
# Text(0,0.5,'recall')

# %% [markdown]
# Watts Strogatz with 10,000 nodes with degree $K = 80$, and $\beta = 0.2$. $b$ generated from 30 nonzero entries drawn from a $Normal(75,9)$ distribution. 1000 iterations of ADMM with $\rho = 0.5$ and $\lambda = 0.019$.

# %%
result3 = pd.read_table("WS_10000-20-02b+0e+100n_normal*3+75_sparse_seed1_05rho_00019lambda.txt",
                        header = None,
             names = ["Avg_Pred","Avg_Gen","Approx_Random"])

# %%
ax = result3.plot(title = "WS(10000,80,0.2); b = 30xN(75,9); lambda = 0.0019", x = np.arange(1,5002,10))
ax.set_xlabel("top k nodes")
ax.set_ylabel("recall")
# Out:
# Text(0,0.5,'recall')

# %% [markdown]
# Watts Strogatz with 10,000 nodes with degree $K = 80$, and $\beta = 0.2$. Dense $b$ generated from entries drawn from a $Normal(0,100)$ distribution. 1000 iterations of ADMM with $\rho = 0.5$ and $\lambda = 0.019$.

# %%
result4 = pd.read_table("WS_10000-20-02b+0e+100n_normal*10_dense_seed1_05rho_0001lambda.txt",
                        header = None,
             names = ["Avg_Pred","Avg_Gen","Approx_Random"])

# %%
ax = result4.plot(title = "Grid(100x100); b = dense N(0,100); lambda = 0.001", x = np.arange(1,5002,10))
ax.set_xlabel("top k nodes")
ax.set_ylabel("recall")
# Out:
# Text(0,0.5,'recall')
